# %%
import pandas as pd
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.' ], 
              'Sue': ['Pretty good.', 'Bland.']}, 
               index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
U = pd.DataFrame({'Apple': [20], 
              'Banana': [31]}, 
               index=['Số lượng'])
print (U.T)
# T là transpose ma trận đảo 3*2 thành 2*3
# Out:
#         Số lượng
# Apple         20
# Banana        31

# %%
wine_reviews = pd.read_csv("winemag-data-130k-v2.csv", index_col=0)
wine_reviews.head(6)
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
# 5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
#
# ...

# %%
wine_reviews['description'].head(5)
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# 4    Much like the regular bottling from 2012, this...
# Name: description, dtype: object

# %%
wine_reviews[['country', 'price']].sample(5)
# Out:
#           country  price
# 91255    Portugal   10.0
# 92674          US   35.0
# 103109  Argentina   19.0
# 117973      Spain   30.0
# 43427     Germany   23.0

# %%
wine_reviews.iloc[0]
# Out:
# country                                                            Germany
# description              Notes of honeysuckle and cantaloupe sweeten th...
# designation                         Brauneberger Juffer-Sonnenuhr Spätlese
# points                                                                  90
# price                                                                   28
# province                                                             Mosel
# region_1                                                               NaN
# region_2                                                               NaN
# taster_name                                             Anna Lee C. Iijima
# taster_twitter_handle                                                  NaN
# title                    Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# variety                                                           Riesling
# ...

# %%
#pd.Series([1, 2, 3, 4, 5])
# A2 = pd.Series([5,4,3,2,1])
# pd.DataFrame({A1,A2})

pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
pd.Series([1, 2, 3, 4, 5])
pd.Series(['4 cups', '1 can', '2 large', '1 can' ], index=['Flour', 'Milk', 'Egg', 'Spam'], name='Product A')
# Out:
# Flour     4 cups
# Milk       1 can
# Egg      2 large
# Spam       1 can
# Name: Product A, dtype: object

# %%
wine_reviews.iloc[-5:]
# Đang lấy 5 bạn cuối từ dưới lên
# lấy phần index - hàng ngang, 
# lấy index lấy iloc nếu là số[] 
# Index không phải là số thì dùng loc[] vừa chữ vừa số
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
wine_reviews.loc[0:10, 'country']
# Out:
# 0        Italy
# 1     Portugal
# 2           US
# 3           US
# 4           US
# 5        Spain
# 6        Italy
# 7       France
# 8      Germany
# 9       France
# 10          US
# Name: country, dtype: object

# %%
wine_reviews[['description']]
#same as => wine_reviews.description
# Out:
#                                               description
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
# [129971 rows x 1 columns]

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') & (wine_reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# 133      Italy  Einaudi's wines have been improving lately, an...
# 135      Italy  The color is just beginning to show signs of b...
# 140      Italy  A big, fat, luscious wine with plenty of toast...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 120           Bricco Rocche Prapó      92   70.0           Piedmont
# ...

# %%
first_descriptions = wine_reviews.description[0:10]
print(first_descriptions)
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# 4    Much like the regular bottling from 2012, this...
# 5    Blackberry and raspberry aromas show a typical...
# 6    Here's a bright, informal red that opens with ...
# 7    This dry and restrained wine offers spice in p...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, dtype: object

# %%
sample_reviews_1 = wine_reviews.description [0:10:2]
print (sample_reviews_1)
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 2    Tart and snappy, the flavors of lime flesh and...
# 4    Much like the regular bottling from 2012, this...
# 6    Here's a bright, informal red that opens with ...
# 8    Savory dried thyme notes accent sunnier flavor...
# Name: description, dtype: object

# %%
sample_reviews_0 = wine_reviews.description [[1,5,3]]
print (sample_reviews_0)
# Out:
# 1    This is ripe and fruity, a wine that is smooth...
# 5    Blackberry and raspberry aromas show a typical...
# 3    Pineapple rind, lemon pith and orange blossom ...
# Name: description, dtype: object

# %%
sample_reviews_2 = wine_reviews.loc[[1,10,100],['country','province', 'region_1','region_2']]
print (sample_reviews_2)
# Out:
#       country    province      region_1      region_2
# 1    Portugal       Douro           NaN           NaN
# 10         US  California   Napa Valley          Napa
# 100        US    New York  Finger Lakes  Finger Lakes

# %%
wine_reviews.loc[:10]['country']
# Out:
# 0        Italy
# 1     Portugal
# 2           US
# 3           US
# 4           US
# 5        Spain
# 6        Italy
# 7       France
# 8      Germany
# 9       France
# 10          US
# Name: country, dtype: object

# %%
# Nếu index là số, hàm iloc hoạt động nhưu numpy - không lấy phần tử cuối cùng
# Tuy nhiên khi idex là chữ, hàm loc lấy cả giá trị cuối cùng
wine_reviews.loc[:99,['country','variety']]
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# 2         US                Pinot Gris
# 3         US                  Riesling
# 4         US                Pinot Noir
# ..       ...                       ...
# 95    France                     Gamay
# 96    France                     Gamay
# 97        US                  Riesling
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
 wine_reviews.loc[wine_reviews.country.isin(['Italy', 'France']) & (wine_reviews.points >= 90)]
# Out:
#        country                                        description  \
# 119     France  Medium-gold in color. Complex and inviting nos...
# 120      Italy  Slightly backward, particularly given the vint...
# 126     France  Mid-gold color. Pronounced and enticing aromas...
# 127     France  Attractive mid-gold color with intense aromas ...
# 128     France  Compelling minerality on the nose, Refined and...
# ...        ...                                                ...
# 129964  France  Initially quite muted, this wine slowly develo...
# 129965  France  While it's rich, this beautiful dry wine also ...
# 129968  France  Well-drained gravel soil gives this wine its c...
# 129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970  France  Big, rich and off-dry, this is powered by inte...
#
#                                        designation  points  price  province  \
# 119     Schoenenbourg Grand Cru Vendanges Tardives      92   80.0    Alsace
# ...

# %%
f = lambda x,y: x/y
f(1,2)
# Out:
# 0.5

# %%
wine_reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
 wine_reviews.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
wine_review_points_mean = wine_reviews.points.mean()
def minus_mean(v):
    return v - wine_review_points_mean

A = wine_reviews.points.map(minus_mean)
print(A)
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
import numpy as np
review_points_mean = wine_reviews.points.mean()
print ('Mean:',review_points_mean)

def minus_mean(v):
   return v - review_points_mean

A = wine_reviews.points.map(minus_mean)
print(A)
# Out:
# Mean: 88.44713820775404
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
#def remean_points(row):
#    row.points = row.points - review_points_mean
#    return row

"hai bạn này tương đương nhau"

wine_reviews.head(100).apply(lambda r: r.points - review_points_mean, axis= 1) # axis = "index"
# Out:
# 0    -1.447138
# 1    -1.447138
# 2    -1.447138
# 3    -1.447138
# 4    -1.447138
#         ...
# 95   -0.447138
# 96   -0.447138
# 97   -0.447138
# 98   -0.447138
# 99   -0.447138
# Length: 100, dtype: float64

# %%
review_points_median = wine_reviews.points.median()
print(review_points_median)
# Out:
# 88.0

# %%
print (wine_reviews.points/wine_reviews.price)
# Out:
# 0              NaN
# 1         5.800000
# 2         6.214286
# 3         6.692308
# 4         1.338462
#             ...
# 129966    3.214286
# 129967    1.200000
# 129968    3.000000
# 129969    2.812500
# 129970    4.285714
# Length: 129971, dtype: float64

# %%
#Bài 6: Một chai vang thì có thể được gán tính từ nhiệt đới hay là có vị trái cây. 
#Tạo một Series desc_counts đếm số lần mỗi từ tropical hay fruity xuất hiện trong cột mô tả
wine_reviews.description.map(lambda desc:'Fruit'in desc).value_counts()

# dùng value_counts() hoặc sum() đều được
# Out:
# False    129321
# True        650
# Name: description, dtype: int64

# %%
#

# %%
 wine_reviews.sample()
# Out:
#       country                                        description  \
# 42675      US  Fresh, fruity cranberry and raspberry flavors ...
#
#                     designation  points  price  province      region_1  \
# 42675  Cabernet Franc-Lemberger      87   22.0  New York  Finger Lakes
#
#            region_2         taster_name taster_twitter_handle  \
# 42675  Finger Lakes  Anna Lee C. Iijima                   NaN
#
#                                                    title    variety  \
# 42675  Anthony Road 2013 Cabernet Franc-Lemberger Red...  Red Blend
#
#              winery
# 42675  Anthony Road

# %%
wine_reviews.shape[0]
#Row number
# Out:
# 129971

# %%
 wine_reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
 wine_reviews .country.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
#wine_reviews.groupby('points').points.count()
wine_reviews.groupby('price').max()
# Out:
#                                               description  points  \
# price
# 4.0     Tropical fruit and citrus aromas aren't bad, b...      86
# 5.0     While this smells floral and candied, the pala...      87
# 6.0     With solid peach aromas and an otherwise clean...      88
# 7.0     lean and zesty Chardonnay with a burst of mout...      91
# 8.0     here too many Pinot Grigios are sweet and suga...      91
# ...                                                   ...     ...
# 1900.0  A massive wine for Margaux, packed with tannin...      98
# 2000.0  This extravagantly perfumed wine has great jui...      97
# 2013.0  The nose on this single-vineyard wine from a s...      91
# 2500.0  The wine is a velvet glove in an iron fist. Th...      96
# 3300.0  This ripe wine shows plenty of blackberry frui...      88
#
#                                                     title  \
# price
# 4.0      Terrenal 2010 Estate Bottled Tempranillo (Yecla)
# ...

# %%
H = wine_reviews.groupby('price').points.max()
print (H[::-1])
# Out:
# price
# 3300.0    88
# 2500.0    96
# 2013.0    91
# 2000.0    97
# 1900.0    98
#           ..
# 8.0       91
# 7.0       91
# 6.0       88
# 5.0       87
# 4.0       86
# Name: points, Length: 390, dtype: int64

# %%
wine_reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
wine_reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])

#Nghe nói là cách 2:
def get_best_wine(group):
    return group.loc[group.points.idxmax()]

# Ở đây, ta chỉ hiển thị 2 cột 
wine_reviews.groupby(['country', 'province'])['points',  'title'].apply(get_best_wine)

#wine_reviews.groupby(['country', 'province'])['idxmax'].apply(get_best_wine) 
# Question !!!
# Gỉa thuyết 1:  object Nhóm B phải lớn hơn hoặc bằng nhóm A


wine_reviews.groupby('price').points.max()
# Câu trên là liệt kê các loại vang cao điểm nhất nhất trong mỗi nhóm giá
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
  
#Question: Tại sao phải đi kèm với các hàm max(), min()
# lấy giá trị của trường gần nhất

# %%
 wine_reviews.loc[wine_reviews['description'].str.contains('Fruits') ]
# Lấy ra kết quả ở cột description có word Fruits - kiến thức ngoài lề
# Out:
#        country                                        description  \
# 19566       US  Fruits, flowers and spice should lead the nose...
# 100194      US  Winemaker Isabelle Meunier (ex-Evening Land) h...
#
#             designation  points  price province           region_1  \
# 19566    Estate Bottled      80   15.0     Ohio               Ohio
# 100194  Tualatin Estate      92   65.0   Oregon  Willamette Valley
#
#                  region_2      taster_name taster_twitter_handle  \
# 19566                 NaN  Susan Kostrzewa         @suskostrzewa
# 100194  Willamette Valley     Paul Gregutt           @paulgwine
#
#                                                     title     variety  \
# 19566          Hermes 2006 Estate Bottled Nebbiolo (Ohio)    Nebbiolo
# 100194  Lavinea 2014 Tualatin Estate Pinot Noir (Willa...  Pinot Noir
#
#          winery    idxmax  star_ratings
# 19566    Hermes  5.333333             1
# 100194  Lavinea  1.415385             2

# %%
#def get_mean(price):
    
    
wine_reviews.groupby(['country', 'province'])['price','points'].agg([max, min])
# Ideas: Muốn hiển thị cả mean của point và price thì như nào?
# Solutions: Tạo một def tính mean và cho vô
# Out:
#                             price       points
#                               max   min    max min
# country   province
# Argentina Mendoza Province  230.0   4.0     97  80
#           Other             150.0   7.0     95  80
# Armenia   Armenia            15.0  14.0     88  87
# Australia Australia Other   130.0   5.0     93  80
#           New South Wales   125.0   8.0     94  82
# ...                           ...   ...    ...  ..
# Uruguay   Juanico           130.0  10.0     90  80
#           Montevideo         60.0  17.0     91  83
#           Progreso           46.0  12.0     90  82
#           San Jose           50.0  20.0     87  82
#           Uruguay            50.0  12.0     91  81
#
# [425 rows x 4 columns]

# %%
N = wine_reviews.groupby(['country', 'province']).description.agg([len])
N.sort_values(by=['len'], ascending=False)
# Out:
#                                 len
# country      province
# US           California       36247
#              Washington        8639
# France       Bordeaux          5941
# Italy        Tuscany           5897
# US           Oregon            5373
# ...                             ...
# Croatia      Krk                  1
# New Zealand  Gladstone            1
# South Africa Piekenierskloof      1
# Chile        Coelemu              1
# Greece       Beotia               1
#
# [425 rows x 1 columns]

# %%
countries_reviewed = wine_reviews.groupby(['country', 'province']).description.agg([len])
mi = countries_reviewed.index
type(mi)
print(mi)
#Bài copy mẫu với Multi-index
# Out:
# MultiIndex([('Argentina',  'Mendoza Province'),
#             ('Argentina',             'Other'),
#             (  'Armenia',           'Armenia'),
#             ('Australia',   'Australia Other'),
#             ('Australia',   'New South Wales'),
#             ('Australia',   'South Australia'),
#             ('Australia',          'Tasmania'),
#             ('Australia',          'Victoria'),
#             ('Australia', 'Western Australia'),
#             (  'Austria',           'Austria'),
#             ...
#             (       'US',        'Washington'),
#             (       'US', 'Washington-Oregon'),
#             (  'Ukraine',           'Ukraine'),
#             (  'Uruguay',         'Atlantida'),
#             (  'Uruguay',         'Canelones'),
#             (  'Uruguay',           'Juanico'),
#             (  'Uruguay',        'Montevideo'),
#             (  'Uruguay',          'Progreso'),
#             (  'Uruguay',          'San Jose'),
# ...

# %%
# Ai là người review vang nhiều nhất? 
# Tạo một Series với index là taster_twitter_handle và giá trị là số lần mỗi người review viết.
#Cách 1:
wine_reviews.groupby('taster_twitter_handle').size()
# giá trị ko được sắp xếp
# Cách 2: 
wine_reviews.taster_twitter_handle.value_counts()
# Out:
# @vossroger          25514
# @wineschach         15134
# @kerinokeefe        10776
# @vboone              9537
# @paulgwine           9532
# @mattkettmann        6332
# @JoeCz               5147
# @wawinereport        4966
# @gordone_cellars     4177
# @AnneInVino          3685
# @laurbuzz            1835
# @suskostrzewa        1085
# @worldwineguys       1005
# @bkfiona               27
# @winewchristina         6
# Name: taster_twitter_handle, dtype: int64

# %%
# có $400, tìm tên loại vang ngon nhất mà tôi có thể mua với số tiền đang có? 
# Chưa chắc đã đúng!
Q = wine_reviews.loc[(wine_reviews.price <= 400)]

Q.groupby([ 'price'])['points'].agg(max)

# %%
# Giá tiền thấp nhất và cao nhất cho mỗi variety của vang là gì? 
# Tạo một DataFrame có index là danh mục variety và giá trị là min và max của giá. (gợi ý: dùng agg())
wine_reviews.groupby(['variety'])['price'].agg([max, min])
# Out:
#                max   min
# variety
# Abouriou      75.0  15.0
# Agiorgitiko   66.0  10.0
# Aglianico    180.0   6.0
# Aidani        27.0  27.0
# Airen         10.0   8.0
# ...            ...   ...
# Zinfandel    100.0   5.0
# Zlahtina      16.0  13.0
# Zweigelt      70.0   9.0
# Çalkarası     19.0  19.0
# Žilavka       15.0  15.0
#
# [707 rows x 2 columns]

# %%
# Những loại vang đắt tiền nhất trong mỗi nhóm là gì? 
# Tạo biến sorted_varieties với giá trị từ câu trước được sắp xếp theo thứ tự giảm dần dựa vào giá min, sau đó là giá max.
W = wine_reviews.groupby(['variety'])['price' ].agg([max])
W.sort_values(by=['max'], ascending=False)
 #Làm với min - the same
# Out:
#                                    max
# variety
# Bordeaux-style Red Blend        3300.0
# Pinot Noir                      2500.0
# Chardonnay                      2013.0
# Grüner Veltliner                1100.0
# Bordeaux-style White Blend      1000.0
# ...                                ...
# Roscetto                           NaN
# Sauvignon Blanc-Sauvignon Gris     NaN
# Tempranillo-Malbec                 NaN
# Vital                              NaN
# Zelen                              NaN
#
# [707 rows x 1 columns]

# %%
# Tạo một Series có index là những người review và values là điểm review trung bình của người đó 
# (gợi ý: cần các cột taster_name và points)
E = wine_reviews.groupby(['taster_name']).points.sum() / wine_reviews.groupby('taster_name').size()  
print (E)
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# dtype: float64

# %%
# Nhóm nước và loại vang nào là phổ biến nhất? 
# Tạo một Series có index là một MultiIndex của cặp {country, variery}. 
# Sắp xếp giá trị torng Series theo thứ tự giảm dần dựa vào số lượng vang đếm được. 
# (gợi ý: dùng groupby() rồi đếm trên variety sau đó sort_values().)
E = wine_reviews.groupby('country').size()
E.sort_values(ascending=False).reset_index()
# Out:
#                    country      0
# 0                       US  54504
# 1                   France  22093
# 2                    Italy  19540
# 3                    Spain   6645
# 4                 Portugal   5691
# 5                    Chile   4472
# 6                Argentina   3800
# 7                  Austria   3345
# 8                Australia   2329
# 9                  Germany   2165
# 10             New Zealand   1419
# 11            South Africa   1401
# 12                  Israel    505
# 13                  Greece    466
# 14                  Canada    257
# 15                 Hungary    146
# 16                Bulgaria    141
# 17                 Romania    120
# 18                 Uruguay    109
# 19                  Turkey     90
# 20                Slovenia     87
# 21                 Georgia     86
# 22                 England     74
# 23                 Croatia     73
# 24                  Mexico     70
# 25                 Moldova     59
# ...

# %%
# Tạo một Series có index là một MultiIndex của cặp {country, variery}.
Cau_466 = wine_reviews.groupby(['country', 'variety']).description.agg([len])
T = Cau_466.index
print(T)
# Out:
# MultiIndex([('Argentina',                           'Barbera'),
#             ('Argentina',                           'Bonarda'),
#             ('Argentina',          'Bordeaux-style Red Blend'),
#             ('Argentina',        'Bordeaux-style White Blend'),
#             ('Argentina',                    'Cabernet Blend'),
#             ('Argentina',                    'Cabernet Franc'),
#             ('Argentina', 'Cabernet Franc-Cabernet Sauvignon'),
#             ('Argentina',             'Cabernet Franc-Malbec'),
#             ('Argentina',                'Cabernet Sauvignon'),
#             ('Argentina', 'Cabernet Sauvignon-Cabernet Franc'),
#             ...
#             (  'Uruguay',                        'Pinot Noir'),
#             (  'Uruguay',                         'Red Blend'),
#             (  'Uruguay',                              'Rosé'),
#             (  'Uruguay',                   'Sauvignon Blanc'),
# ...

# %%
# Sắp xếp giá trị torng Series theo thứ tự giảm dần dựa vào số lượng vang đếm được. 
Y = wine_reviews.groupby('variety').size()
Y.sort_values(ascending=False).reset_index()
# Out:
#                       variety      0
# 0                  Pinot Noir  13272
# 1                  Chardonnay  11753
# 2          Cabernet Sauvignon   9472
# 3                   Red Blend   8946
# 4    Bordeaux-style Red Blend   6915
# ..                        ...    ...
# 702                  Ojaleshi      1
# 703                    Ondenc      1
# 704               Catalanesca      1
# 705              Orangetraube      1
# 706                   Žilavka      1
#
# [707 rows x 2 columns]

# %%
def get_star_ratings(row):
                if row.country == 'Canada':
                   return 3
                if row.points >= 95:
                    return 3
                elif row.points >= 85:
                    return 2
                else:
                    return 1    
star_ratings.value_counts()
#Bài buổi trước về hàm apply
# Out:
# 2    114877
# 1     12421
# 3      2673
# dtype: int64

# %%
wine_reviews.head(5)
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
def get_star_ratings(row):
                if row.country == 'Canada':
                   return 3
                if row.points >= 95:
                    return 3
                elif row.points >= 85:
                    return 2
                else:
                    return 1    
wine_reviews['star_ratings'] = wine_reviews.apply(get_star_ratings, axis=1)
wine_reviews.head(5)
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_reviews.groupby(['country', 'province']).mean()
# Out:
#                                points      price    idxmax  star_ratings
# country   province
# Argentina Mendoza Province  86.826593  25.053317  5.119496      1.742953
#           Other             86.001866  21.203774  5.488273      1.695896
# Armenia   Armenia           87.500000  14.500000  6.040476      2.000000
# Australia Australia Other   85.518367  12.427966  8.010896      1.681633
#           New South Wales   87.694118  25.623529  4.778116      1.882353
# ...                               ...        ...       ...           ...
# Uruguay   Juanico           86.333333  48.583333  3.708941      1.666667
#           Montevideo        88.272727  26.090909  3.863006      1.909091
#           Progreso          86.818182  24.272727  4.436341      1.818182
#           San Jose          84.000000  30.000000  3.330000      1.333333
#           Uruguay           86.833333  22.083333  4.425196      1.833333
#
# [425 rows x 4 columns]

# %%
wine_reviews.groupby('taster_name').size().reset_index()
# Out:
#            taster_name      0
# 0   Alexander Peartree    415
# 1   Anna Lee C. Iijima   4415
# 2     Anne Krebiehl MW   3685
# 3         Carrie Dykes    139
# 4    Christina Pickard      6
# 5          Fiona Adams     27
# 6         Jeff Jenssen    491
# 7           Jim Gordon   4177
# 8       Joe Czerwinski   5147
# 9        Kerin O’Keefe  10776
# 10       Lauren Buzzeo   1835
# 11       Matt Kettmann   6332
# 12   Michael Schachner  15134
# 13       Mike DeSimone    514
# 14        Paul Gregutt   9532
# 15          Roger Voss  25514
# 16    Sean P. Sullivan   4966
# 17     Susan Kostrzewa   1085
# 18      Virginie Boone   9537

# %%
# có $400, tìm tên loại vang ngon nhất mà tôi có thể mua với số tiền đang có? 
O = wine_reviews.groupby(['price'])["points"].max().reset_index()
O[O.price<=400]
# TẠO THÊM CỘT INDEX
# Out:
#      price  points
# 0      4.0      86
# 1      5.0      87
# 2      6.0      88
# 3      7.0      91
# 4      8.0      91
# ..     ...     ...
# 299  391.0      93
# 300  395.0      95
# 301  398.0      95
# 302  399.0      95
# 303  400.0      96
#
# [304 rows x 2 columns]

# %%
wine_reviews.groupby('country').max()[['description','province']]
#Cách 2: wine_reviews.groupby('country')[ 'province','description'].max()

# %%
# điểm vang cao nhất của dòng vang đó và giá tiền của chai thấp nhất cùng dòng.
